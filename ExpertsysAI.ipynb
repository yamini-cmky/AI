# %% [markdown]
# <a href="https://colab.research.google.com/github/yamini-cmky/AI/blob/main/ExpertsysAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def product(age):
    if age >= 55:
        print("saving plan")
    elif age >= 12 and age <= 18:
        print("video game")
    elif age >= 25 and age <= 28:
        print("MOBILE")
    elif age >= 25 and age <= 35:
        print("LAPTOP")
    elif age >= 35 and age <= 55:
        print("LAPTOP")



age=int(input("Enter age"))
product(age)
# Out:
# Enter age56
# saving plan

# %%
print("Using Upper Case:","Hello World by yamini".upper())
print("Using Lower Case:","Hello World by yamini".lower())
print("Using Title Case:","Hello World by yamini".title())
print("Using Capitalize Case:","hello World by yamini".capitalize())
print("Using Strip Case:","  hello World by yamini  ".strip())
print("Using Capitalize Case:","hello World by yamini".replace('yamini','sunanda'))
print("Using Split Case:","hello World by yamini".split(','))
print("Using Join Case:","hello World by yamini".join('yamini'))
print("Using Center Case:","hello World by yamini".center(10))
print("Using Count Case:","hello World by yamini".count('yamini'))
print("Using Endswith Case:","hello World by yamini".endswith('yamini'))
print("Using Startswith Case:","hello World by yamini".startswith('yamini'))
# Out:
# Using Upper Case: HELLO WORLD BY YAMINI
# Using Lower Case: hello world by yamini
# Using Title Case: Hello World By Yamini
# Using Capitalize Case: Hello world by yamini
# Using Strip Case: hello World by yamini
# Using Capitalize Case: hello World by sunanda
# Using Split Case: ['hello World by yamini']

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("xhlulu/medal-emnlp")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/medal-emnlp

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# Load dataset
df = pd.read_csv(url)
print("Using Upper Case:",df.upper())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-14-2332505634.py in <cell line: 0>()
#       5 # Load dataset
#       6 df = pd.read_csv(url)
# ----> 7 print("Using Upper Case:",df.upper())
#       8
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'upper'

# %%
import pandas as pd

url = "https://www.kaggle.com/datasets/xhlulu/medal-emnlp"

# Load dataset
df = pd.read_csv(url)

print("✅ Titanic Dataset downloaded and loaded successfully!\n")
print(df)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-10-4281817591.py in <cell line: 0>()
#       4
#       5 # Load dataset
# ----> 6 df = pd.read_csv(url)
#       7
#       8 print("✅ Titanic Dataset downloaded and loaded successfully!\n")
#
# ...

# %%
import pandas as pd

url = "https://www.kaggle.com/datasets/rakeshkapilavai/extrovert-vs-introvert-behavior-data/content/personality_datasert.csv"

# Load dataset
df = pd.read_csv(url)

print("✅ Titanic Dataset downloaded and loaded successfully!\n")
print(df)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-2573795335.py in <cell line: 0>()
#       4
#       5 # Load dataset
# ----> 6 df = pd.read_csv(url)
#       7
#       8 print("✅ Titanic Dataset downloaded and loaded successfully!\n")
#
# ...

# %%
import pandas as pd

df = pd.read_csv("personality_datasert.csv")
print("✅ Dataset loaded successfully!\n")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3-2025472801.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("personality_datasert.csv")
#       4 print("✅ Dataset loaded successfully!\n")
#       5 print(df.head())
#
# ...

# %%
#Recomandded system
def clothing():
    age=int(input("Enter age"))
print("Clothing Recomendation")
if age >= 55:
  print("Warm colthes")
elif age >= 12 and age <= 18:
  print("Funky cloths")
elif age >= 25 and age <= 28:
  print("Formal cloths")
elif age >= 25 and age <= 35:
  print("Casual cloths")
elif age >= 35 and age <= 55:
  print("Formal cloths")
def electronics():
  print("Electronics Recomendation")
  print("Mobile")
  print("Laptop")
def grocaries():
  print("Grocaries Recomendation")
  print("Fruits")
  print("Vegetables")

def kitchen():
  print("Kitchen Recomendation")
  print("Utensils")
  print("Utensils")
def mobiles():
  print("Samsung")
  print("Oppo")
  print("IPhone")

print("Shopping recomandded systems")
print("1. Clothing")
print("2.Electronics")
print("3.Grocaries")
print("4. Kitchen")
print("5. Mobiles")

n=int(input("Enter  the option"))
match(n):
  case 1: clothing()
  case 2: electronics()
  case 3: grocaries()
  case 4: kitchen()
  case 5: mobiles()
  case _:
    print("Invalid option")
# Out:
# Clothing Recomendation
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-2553129884.py in <cell line: 0>()
#       3     age=int(input("Enter age"))
#       4 print("Clothing Recomendation")
# ----> 5 if age >= 55:
#       6   print("Warm colthes")
#       7 elif age >= 12 and age <= 18:
#
# NameError: name 'age' is not defined

# %%
#Recomandded system
def clothing():
  age=int(input("Enter the age"))
  if age<=15:
    print("Teenager clothes")
  elif age>=16 and age<=25:
    print("youth clothes ")
  elif age>=26 and age<35:
    print(" Formal clothes")
  elif age>=35:
    print("Professional clothes")


def electronics():
  budget=int(input("Enter the budget"))
  if budget<=15000:
    print("Mobile")
  elif budget>=15000 and budget<=25000:
    print("Laptop")

  def grocaries():
    prize=int(input("Enter the prize"))
    if prize<=150:
      print("Fruits")
    elif prize>=150 and prize<=250:
      print("Vegetables")


def kitchen():
  prize=int(input("Enter the prize"))
  if prize<=150:
    print("Utensils")
  elif prize>=150 and prize<=250:
    print


def mobiles():
  prize = int(input("Enter the prize "))
  if prize <= 15000:
    print("Samsung")
  elif prize >= 15000 and prize <= 25000:
    print("Oppo")
  elif prize >= 25000:
    print("IPhone")



print("Shopping recomandded systems")
print("1. Clothing")
print("2.Electronics")
print("3.Grocaries")
print("4. Kitchen")
print("5. Mobiles")

n=int(input("Enter  the option"))
match(n):
  case 1: clothing()
  case 2: electronics()
  case 3: grocaries()
  case 4: kitchen()
  case 5: mobiles()
  case _:
    print("Invalid option")

# %%
# Meal recomandation System
def Breakfast():
  cal=int(input("Enter cal required:"))

  print("Breakfast")


print("Shopping recomandded systems")
print("1. Breakfast")
print("2.Lunch")
print("3. Snacks")
print("4. Dinner")

n=int(input("Enter  the option"))
match(n):
  case 1: Breakfast()
  case 2: Lunch()
  case 3: Snacks()
  case 4: Dinner()

  case _:
    print("Invalid option")

# %%
def diagnosis(symptoms):
    if "Fever" in symptoms and "Headache" in symptoms and "Body pains" in symptoms:
        print("You may have Flu")
    elif "High BP" in symptoms and "High Cholesterol" in symptoms and "Thick blood" in symptoms:
        print("You may have Heart issues")
    elif "High fever" in symptoms and "Breathing issues" in symptoms and "Throat infections" in symptoms:
        print("You may have COVID")
    else:
        print("Please consult a doctor for further checkup")

print("Choose your symptoms by typing numbers (separated by space):")
print("1. Clothing")
print("2. Kitchen")
.
print("3. Electronic")
print("4. GIFT")


symptom_map = {
    '1': "Clothing",
    '2': "Kitchen",
    '3': "Electronic",
    '4': "GIFT",

}

# Input
prod = input("Enter numbers: ").split()
symptoms = [symptom_map[n] for n in numbers if n in symptom_map]

diagnosis(symptoms)

# %%
def diagnosis(sym):
    if "Clothing" in symptoms and "Kitchen" in symptoms:
        print("You may be shopping for Home Essentials")
    elif "Electronic" in symptoms and "GIFT" in symptoms:
        print("You may be shopping for a Celebration")
    else:
        print("Please browse more categories")

print("Choose your symptoms by typing numbers (separated by space):")
print("1. Clothing")
print("2. Kitchen")
print("3. Electronic")
print("4. GIFT")

symptom_map = {
    '1': "Clothing",
    '2': "Kitchen",
    '3': "Electronic",
    '4': "GIFT",
}

# Input
prod = input("Enter numbers: ").split()
sym = [symptom_map[n] for n in prod if n in symptom_map]

diagnosis(sym)
# Out:
# Choose your symptoms by typing numbers (separated by space):
# 1. Clothing
# 2. Kitchen
# 3. Electronic
# 4. GIFT
# Enter numbers: 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4-2957358461.py in <cell line: 0>()
#      24 sym = [symptom_map[n] for n in prod if n in symptom_map]
#      25
# ---> 26 diagnosis(sym)
#
# /tmp/ipython-input-4-2957358461.py in diagnosis(sym)
#       1 def diagnosis(sym):
# ----> 2     if "Clothing" in symptoms and "Kitchen" in symptoms:
#       3         print("You may be shopping for Home Essentials")
#       4     elif "Electronic" in symptoms and "GIFT" in symptoms:
#       5         print("You may be shopping for a Celebration")
#
# NameError: name 'symptoms' is not defined

# %%
def diagnosis(sym):
    if "Clothing" in sym and "Kitchen" in sym:
        print("You may be shopping for Home Essentials")
    elif "Electronic" in sym and "GIFT" in sym:
        print("You may be shopping for a Celebration")
    else:
        print("Please browse more categories")

print("Choose your symptoms by typing numbers (separated by space):")
print("1. Clothing")
print("2. Kitchen")
print("3. Electronic")
print("4. GIFT")

symptom_map = {
    '1': "Clothing",
    '2': "Kitchen",
    '3': "Electronic",
    '4': "GIFT",
}

# Input
prod = input("Enter numbers: ").split()
sym = [symptom_map[n] for n in prod if n in symptom_map]

diagnosis(sym)
# Out:
# Choose your symptoms by typing numbers (separated by space):
# 1. Clothing
# 2. Kitchen
# 3. Electronic
# 4. GIFT
# Enter numbers: 4
# Please browse more categories

# %%
import requests

# URL of the text file
text = "https://www.gutenberg.org/files/1524/1524-0.txt"

# send HTTP GET request
response = requests.get(text)

# get the text content
content = response.text

print(content)  # prints the whole text

print("Using Capitalize Case:",content.capitalize())
print("Using Strip Case:",content.strip())
# Out:
# ﻿The Project Gutenberg eBook of Hamlet, by William Shakespeare
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online at
# www.gutenberg.org. If you are not located in the United States, you
# will have to check the laws of the country where you are located before
# using this eBook.
#
# Title: Hamlet
#
# Author: William Shakespeare
#
# Release Date: November 1998 [eBook #1524]
# [Most recently updated: November 9, 2023]
#
# Language: English
#
# Produced by: Dianne Bean
#
# *** START OF THE PROJECT GUTENBERG EBOOK HAMLET ***
#
#
#
#
# cover
#
#
#
#
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK
#
# by William Shakespeare
#
#
#
#
# Contents
#
#  ACT I
#  Scene I. Elsinore. A platform before the Castle
#  Scene II. Elsinore. A room of state in the Castle
# ...
